# %% [markdown]
# <a href="https://colab.research.google.com/github/PranavDscientist/Stroke-prediction/blob/main/Stroke_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/Datasets/stroke.csv')
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
df.isna().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
df.dtypes
# Out:
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
df.drop(['id'],axis=1,inplace=True)

# %%
df
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1     Female  61.0             0              0          Yes  Self-employed
# 2       Male  80.0             0              1          Yes        Private
# 3     Female  49.0             0              0          Yes        Private
# 4     Female  79.0             1              0          Yes  Self-employed
# ...      ...   ...           ...            ...          ...            ...
# 5105  Female  80.0             1              0          Yes        Private
# 5106  Female  81.0             0              0          Yes  Self-employed
# 5107  Female  35.0             0              0          Yes  Self-employed
# 5108    Male  51.0             0              0          Yes        Private
# 5109  Female  44.0             0              0          Yes       Govt_job
#
# ...

# %%
df.tail()
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 5105  Female  80.0             1              0          Yes        Private
# 5106  Female  81.0             0              0          Yes  Self-employed
# 5107  Female  35.0             0              0          Yes  Self-employed
# 5108    Male  51.0             0              0          Yes        Private
# 5109  Female  44.0             0              0          Yes       Govt_job
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 5105          Urban              83.75   NaN     never smoked       0
# 5106          Urban             125.20  40.0     never smoked       0
# 5107          Rural              82.99  30.6     never smoked       0
# 5108          Rural             166.29  25.6  formerly smoked       0
# 5109          Urban              85.28  26.2          Unknown       0

# %%
# filling missing value of bmi
df['bmi']=df['bmi'].fillna(df['bmi'].mean())

# %%
df
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1     Female  61.0             0              0          Yes  Self-employed
# 2       Male  80.0             0              1          Yes        Private
# 3     Female  49.0             0              0          Yes        Private
# 4     Female  79.0             1              0          Yes  Self-employed
# ...      ...   ...           ...            ...          ...            ...
# 5105  Female  80.0             1              0          Yes        Private
# 5106  Female  81.0             0              0          Yes  Self-employed
# 5107  Female  35.0             0              0          Yes  Self-employed
# 5108    Male  51.0             0              0          Yes        Private
# 5109  Female  44.0             0              0          Yes       Govt_job
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,6))
x=df['stroke'].value_counts()
xlabel=['No stroke','Stroke']
plt.pie(x,labels=xlabel,autopct='%1.1f%%')
plt.title('Stroke')
plt.legend(loc='lower left')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='gender', hue='stroke', data=df)
plt.title('Stroke by gender')
plt.show()

# %% [markdown]
# Females are more likely to have stroke

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['gender']=le.fit_transform(df['gender'])
df['ever_married'] = le.fit_transform(df['ever_married'])
df['work_type'] = le.fit_transform(df['work_type'])
df['Residence_type'] = le.fit_transform(df['Residence_type'])
df['smoking_status'] = le.fit_transform(df['smoking_status'])

# %% [markdown]
# Correlation between features

# %%
df.corr()
# Out:
#                      gender       age  hypertension  heart_disease  \
# gender             1.000000 -0.028202      0.020994       0.085447
# age               -0.028202  1.000000      0.276398       0.263796
# hypertension       0.020994  0.276398      1.000000       0.108306
# heart_disease      0.085447  0.263796      0.108306       1.000000
# ever_married      -0.031005  0.679125      0.164243       0.114644
# work_type          0.056422 -0.361642     -0.051761      -0.028023
# Residence_type    -0.006738  0.014180     -0.007913       0.003092
# avg_glucose_level  0.055180  0.238171      0.174474       0.161857
# bmi               -0.026109  0.325942      0.160189       0.038899
# smoking_status    -0.062581  0.265199      0.111038       0.048460
# stroke             0.008929  0.245257      0.127904       0.134914
#
#                    ever_married  work_type  Residence_type  avg_glucose_level  \
# gender                -0.031005   0.056422       -0.006738           0.055180
# ...

# %% [markdown]
# Heat map to show correlation between features

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(),annot=True,linewidths=0.5)
# Out:
# <Axes: >

# %%
df.isna().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
df.dtypes
# Out:
# gender                 int64
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married           int64
# work_type              int64
# Residence_type         int64
# avg_glucose_level    float64
# bmi                  float64
# smoking_status         int64
# stroke                 int64
# dtype: object

# %%
X=df.iloc[:,:-1]
X
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0          1  67.0             0              1             1          2
# 1          0  61.0             0              0             1          3
# 2          1  80.0             0              1             1          2
# 3          0  49.0             0              0             1          2
# 4          0  79.0             1              0             1          3
# ...      ...   ...           ...            ...           ...        ...
# 5105       0  80.0             1              0             1          2
# 5106       0  81.0             0              0             1          3
# 5107       0  35.0             0              0             1          3
# 5108       1  51.0             0              0             1          2
# 5109       0  44.0             0              0             1          0
#
#       Residence_type  avg_glucose_level        bmi  smoking_status
# ...

# %%
y=df.iloc[:,-1]
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 5105    0
# 5106    0
# 5107    0
# 5108    0
# 5109    0
# Name: stroke, Length: 5110, dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
X_scaled=scaler.fit_transform(X)
X_scaled
# Out:
# array([[0.5       , 0.81689453, 0.        , ..., 0.80126489, 0.30126002,
#         0.33333333],
#        [0.        , 0.74365234, 0.        , ..., 0.67902317, 0.21298095,
#         0.66666667],
#        [0.5       , 0.97558594, 0.        , ..., 0.23451205, 0.25429553,
#         0.66666667],
#        ...,
#        [0.        , 0.42626953, 0.        , ..., 0.12865848, 0.2325315 ,
#         0.66666667],
#        [0.5       , 0.62158203, 0.        , ..., 0.51320284, 0.17525773,
#         0.33333333],
#        [0.        , 0.53613281, 0.        , ..., 0.13922999, 0.18213058,
#         0.        ]])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_scaled,y,test_size=0.3,random_state=1)
X_train
# Out:
# array([[0.5       , 0.69482422, 0.        , ..., 0.36764842, 0.21534937,
#         0.        ],
#        [0.        , 0.00976562, 0.        , ..., 0.15229434, 0.05956472,
#         0.        ],
#        [0.5       , 0.24316406, 0.        , ..., 0.13558305, 0.11683849,
#         0.66666667],
#        ...,
#        [0.        , 0.37744141, 0.        , ..., 0.09759025, 0.28980527,
#         0.66666667],
#        [0.        , 0.54833984, 0.        , ..., 0.75237744, 0.51202749,
#         1.        ],
#        [0.        , 0.82910156, 0.        , ..., 0.71987813, 0.33218786,
#         0.        ]])

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred=knn.predict(X_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score,ConfusionMatrixDisplay
print('accuracy',accuracy_score(y_test,y_pred))
print(ConfusionMatrixDisplay.from_predictions(y_test,y_pred))
# Out:
# accuracy 0.9452054794520548
# ...

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      1450
#            1       0.00      0.00      0.00        83
#
#     accuracy                           0.95      1533
#    macro avg       0.47      0.50      0.49      1533
# weighted avg       0.89      0.95      0.92      1533

# %%
from sklearn.svm import SVC
sv=SVC()
sv.fit(X_train,y_train)
# Out:
# SVC()

# %%
y_pred_sv=sv.predict(X_test)
y_pred_sv
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
print('accuracy',accuracy_score(y_test,y_pred_sv))
# Out:
# accuracy 0.9458577951728636

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred_sv))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      1450
#            1       0.00      0.00      0.00        83
#
#     accuracy                           0.95      1533
#    macro avg       0.47      0.50      0.49      1533
# weighted avg       0.89      0.95      0.92      1533

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# predicting new values

# %%
y_new=sv.predict(scaler.transform([[0,61.0,0,0,1,3,0,202.21,28.893237,2]]))
if y_new==1:
  print('stroke')
else:
  print('no stroke')
# Out:
# no stroke
